# %% [markdown]
# # Python Data Structures
# ## Learning Objectives
# - Understand the characteristics and use cases of Python tuples, lists, sets, and dictionaries
# - Apply these data structures to store and manipulate geospatial data, such as coordinates, paths, and attribute information
# - Differentiate betweenm mutable and immutable data structures and choose the appropriate structure for different geospatial tasks
# - Perform common operations on these data structures, including indexing, slicing, adding/removing elements, and updating values
# - Utilize dictionaries to manage geospatial feature attributes and undestand the imporatnce of key-value pairs in geospatial data management
#
# ### Tuples
# Tuples are immutable sequences, onde created you cannot change, add or remove its elements. In geospatial programming tuples are commonly used to represent coordinate pairs, since a point's latitude and longitude typically shouldn't change once defined. *Tuples are memory-efficient*.

# %%
tokyo_point = (35.6895, 139.6917)  # Tuple representing Tokyo's coordinates (latitude, longitude)
print(f"Tokyo coordinates: {tokyo_point}")
# Out:
# Tokyo coordinates: (35.6895, 139.6917)

# %%
# Accessing Tuple Elements
latitude = tokyo_point[0]
longitude = tokyo_point[1]
print(f"Latitude: {latitude}")
print(f"Longitude: {longitude}")
# Out:
# Latitude: 35.6895
# Longitude: 139.6917

# %%
# Tuple Unpacking

lat, lon = tokyo_point # Unpacking into two variables
print(f'Tokyo is located at {lat}°N, {lon}°E')
# Out:
# Tokyo is located at 35.6895°N, 139.6917°E

# %% [markdown]
# ### Lists
# Lists are ordered, mutable sequences that can store multiple items in a single container. Lists are mutable and useful for geospatial applications where you need to build collections of data dynamically, such as tracking a GPS route, storing elevations measurements along a transect, or maintaining a collection of waypoints.
#
# > Lists maintaing the order of elements, which is crucial for geospatial applications where sequence matters.
#
# >Lists can stores different types of data (numbers, strings, tuples, or even other lists)

# %%
# A list of coordinate tuples representing a travel route
route = [
(35.6895, 139.6917),  # Tokyo
(34.0522, -118.2437),  # Los Angeles
(51.5074, -0.1278),  # London
]
print("Travel route:", route)
# Out:
# Travel route: [(35.6895, 139.6917), (34.0522, -118.2437), (51.5074, -0.1278)]

# %%
# A list of elevation measurements (in meters)
elevations = [120.5, 135.2, 150.8, 168.3, 185.7, 203.1]
print("Elevation profile:", elevations)
# Out:
# Elevation profile: [120.5, 135.2, 150.8, 168.3, 185.7, 203.1]

# %%
# A list of city names
cities = ["Tokyo", "Los Angeles", "London", "Paris"]
print("Cities to visit:", cities)
# Out:
# Cities to visit: ['Tokyo', 'Los Angeles', 'London', 'Paris']

# %% [markdown]
# ### Sets
# Sets are unordered collections of unique elements, meaning they automatically eliminate duplicates and don't maintain any particular order. This makes sets incredibly useful in geospatial programming when you need to work with *unique identifiers, remove duplicate entries form datasets*, or perform operations linke finding common elements between differeent spatial datasets.
#
# Sets are particularly valuable when working with categorical spatial data. For example, you might want to track unique country codes in a global dataset, identify distinct land cover types in a study area, or maintain a collection of unique coordinate system identifiers. The automatic duplicate removal feature of sets saves you from having to manually check for and remove repeated values.
#
# You can use curly braces {} to create a set, or use the set() function to convert a list or other iterable into a set

# %%
# Create a set of geographic regions
regions_visited = {"North America", "Europe", "Asia"}
print("Regions visited:", regions_visited)
# Out:
# Regions visited: {'Europe', 'Asia', 'North America'}

# %%
# Create a set from a list (automatically removes duplicates)
country_codes = ["US", "CA", "MX", "US", "CA"]  # Notice the duplicates
unique_codes = set(country_codes)
print("Original list:", country_codes)
print("Unique country codes:", unique_codes)
# Out:
# Original list: ['US', 'CA', 'MX', 'US', 'CA']
# Unique country codes: {'CA', 'MX', 'US'}

# %% [markdown]
# You `can` add new elements to a set, but duplicates will be automatically ignored:

# %%
# Add a new region
print("Original set:", regions_visited)
regions_visited.add("Africa")
print("After adding Africa:", regions_visited)
# Try to add a duplicate region
regions_visited.add("Europe")  # This won't change the set
print("After trying to add Europe again:", regions_visited)
# Out:
# Original set: {'Europe', 'Asia', 'North America'}
# After adding Africa: {'Europe', 'Asia', 'North America', 'Africa'}
# After trying to add Europe again: {'Europe', 'Asia', 'North America', 'Africa'}

# %% [markdown]
# Useful operations for comparing different spatial datasets.<br><br>
# `intersection()` returns a set of elements that are common to both sets<br>
# `union()` returns a set of all elements grom both sets

# %%
# Two different survey areas with their observed species
area_a_species = {"oak", "pine", "maple", "birch"}
area_b_species = {"pine", "birch", "cedar", "fir"}

print("Species in Area A:", area_a_species)
print("Species in Area B:", area_b_species)

# Find species common to both areas
common_species = area_a_species.intersection(area_b_species)
print("Species found in both areas:", common_species)

# Find species unique to Area A
unique_to_a = area_a_species - area_b_species
print("Species only in Area A:", unique_to_a)

# Find all species across both areas
all_species = area_a_species.union(area_b_species)
print("All species found:", all_species)
# Out:
# Species in Area A: {'oak', 'maple', 'pine', 'birch'}
# Species in Area B: {'fir', 'cedar', 'pine', 'birch'}
# Species found in both areas: {'pine', 'birch'}
# Species only in Area A: {'oak', 'maple'}
# All species found: {'fir', 'pine', 'oak', 'cedar', 'maple', 'birch'}

# %% [markdown]
# ### Dictionaries
# Dictionaries are collections of key-value pairs where each key is unique and maps to a specific value

# %%
# Dictionary for a geographic survey point
survey_point = {
"point_id": "SP001",
"latitude": 40.7589,
"longitude": -73.9851,
"elevation": 87.3,
"land_cover": "urban",
"date_surveyed": "2023-06-15",
}
print("Survey point data:", survey_point)
print(survey_point["land_cover"])
# Out:
# Survey point data: {'point_id': 'SP001', 'latitude': 40.7589, 'longitude': -73.9851, 'elevation': 87.3, 'land_cover': 'urban', 'date_surveyed': '2023-06-15'}
# urban

# %%
# Dictionary storing attributes of a city
tokyo_info = {
"name": "Tokyo",
"population": 13929286,
"coordinates": (35.6895, 139.6917),
"country": "Japan",
"established": 1603,
}
print("Tokyo information:", tokyo_info)
# Out:
# Tokyo information: {'name': 'Tokyo', 'population': 13929286, 'coordinates': (35.6895, 139.6917), 'country': 'Japan', 'established': 1603}

# %% [markdown]
# The `get()` method provides a safe way to access dictionary values, allowing you to specify a default value if the key doesn’t exist:

# %%
# Safe access to dictionary values
area = tokyo_info.get("area_km2", "Not specified")
timezone = tokyo_info.get("timezone", "Unknown")
print(f"Area: {area}")
print(f"Timezone: {timezone}")
# Out:
# Area: Not specified
# Timezone: Unknown

# %%
# Add new information to our Tokyo dictionary
tokyo_info["area_km2"] = 2191
tokyo_info["timezone"] = "JST"
tokyo_info["population"] = 14000000  # Update population
print("Updated Tokyo info:", tokyo_info)
# Out:
# Updated Tokyo info: {'name': 'Tokyo', 'population': 14000000, 'coordinates': (35.6895, 139.6917), 'country': 'Japan', 'established': 1603, 'area_km2': 2191, 'timezone': 'JST'}

# %% [markdown]
# Organizing multiple geographic features:

# %%
world_capitals = {
"Japan": {
"capital": "Tokyo",
"coordinates": (35.6895, 139.6917),
"population": 13929286,
},
"France": {
"capital": "Paris",
"coordinates": (48.8566, 2.3522),
"population": 2161000,
},
"UK": {
"capital": "London",
"coordinates": (51.5074, -0.1278),
"population": 8982000,
},
}
# Access information about France's capital
france_info = world_capitals["France"]
print(f"France's capital: {france_info['capital']}")
print(f"Population: {france_info['population']:,}")
# Out:
# France's capital: Paris
# Population: 2,161,000

# %% [markdown]
# #### Dictionary Methods for Data Exploration
# Dictionaries provide useful methods for exploring yout data, such as `keys()`, `values()`, and `items()`.<br>These methods return views of the dictionary's keys, values, and key-values pairs, respectively. They are useful for iterating over the dictionary and for checking if a key exists in the dictionary.

# %%
# Explore the structure of our Tokyo dictionary
print("Keys in tokyo_info:", list(tokyo_info.keys()))
print("Values in tokyo_info:", list(tokyo_info.values()))

# Check if a key exists
if "coordinates" in tokyo_info:
    print("Coordinate information is available")

# Get all countries in our capitals dictionary
countries = list(world_capitals.keys())
print("Countries in our database:", countries)
# Out:
# Keys in tokyo_info: ['name', 'population', 'coordinates', 'country', 'established', 'area_km2', 'timezone']
# Values in tokyo_info: ['Tokyo', 14000000, (35.6895, 139.6917), 'Japan', 1603, 2191, 'JST']
# Coordinate information is available
# Countries in our database: ['Japan', 'France', 'UK']

# %% [markdown]
# #### When to Use Each Data Structure
# Use **Tuples** when:
# - You have a fixed pair or group of values that shouldn’t change (like coordinates)
# - You need to store data that will be used as dictionary keys
# - You want to ensure data integrity by preventing accidental modifications
#
# Use **Lists** when:
# - You need an ordered collection that can change (like a GPS route or waypoint sequence)
# - You want to add, remove, or modify elements dynamically
# - Order matters for your application (like steps in a workflow)
#
# Use **Sets** when:
# - You need to eliminate duplicates from your data
# - You want to perform operations like finding common elements between datasets
# - Order doesn’t matter, but uniqueness does
#
# Use **Dictionaries** when:
# - You need to associate descriptive names with values (like feature attributes)
# - You want fast lookup of information by key
# - You’re organizing complex, structured data about geographic features

# %% [markdown]
# #### Exercise 1: Using Lists
#
# Create a list of tuples, where each tuple contains the name of a city and its corresponding latitude and longitude:
# - New York City: (40.7128, −74.0060)
# - Los Angeles: (34.0522, −118.2437)
# - Chicago: (41.8781, −87.6298)
#
# Tasks:
# 1. Add a new city (e.g., Miami: (25.7617, −80.1918)) to the list
# 2. Print the entire list of cities
# 3. Slice the list to print only the first two cities

# %%
cities = [
     ('New York City', 40.7128, -74.0060),
     ('Los Angeles', 34.0522, -118.2437),
     ('Chicago', 41.8781, -87.6298)
]

cities.append(('Miami', 25.7617, -80.1918))
print(f'The entire list of cities: {cities}')

print(f'Only the first two cities: {cities[0:2]}')
# Out:
# The entire list of cities: [('New York City', 40.7128, -74.006), ('Los Angeles', 34.0522, -118.2437), ('Chicago', 41.8781, -87.6298), ('Miami', 25.7617, -80.1918)]
# Only the first two cities: [('New York City', 40.7128, -74.006), ('Los Angeles', 34.0522, -118.2437)]

# %% [markdown]
# #### Exercise 2: Using Tuples
# Create a tuple to store the coordinates (latitude, longitude) of the Eiffel Tower: (48.8584, 2.2945). Performa the following tasks:
# 1. Acces and print the latitude and longitude values from the tuple.
# 2. Try to change the latitude value to 48.8585. What happens? Explain why.

# %%
eiffel_point = (48.8584, 2.2945)

# 1

lat, lon = eiffel_point
print(lat, lon)

# 2

# The code below doesn't work because tuples are immutable, they don't support item assignment
eiffel_point[0] = 48.8585
# Out:
# 48.8584 2.2945
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 10
#       6 print(lat, lon)
#       8 # 2
# ---> 10 eiffel_point[0] = 48.8585
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# #### Exercise 3: Working with Sets
# Create a set of countries you have visited, such as {'USA','France,'Germany'}. Perform the following tasks:
# 1. Add a new country to the set
# 2. Try to add the same country again. What happens?
# 3. Print the updated set

# %%
countries_visited = {'USA', 'France', 'Germany', 'Peru', 'Brazil', 'Paraguai'}

# 1

countries_visited.add('Italy')
print(countries_visited)

# 2 - The same country can't be added because a set contains only unique values, so it won't contain duplicate values
countries_visited.add('Italy')
print(countries_visited)
# Out:
# {'Peru', 'France', 'Germany', 'USA', 'Paraguai', 'Italy', 'Brazil'}
# {'Peru', 'France', 'Germany', 'USA', 'Paraguai', 'Italy', 'Brazil'}

# %% [markdown]
# ### Exercise 4: Working with Dictionaries
# Create a dictionary to store information about a specific geospatial feature, such as a river:
# - Name: "Amazon River"
# - Length: 6400 km
# - Countries: ["Brazil", "Peru", "Colombia"]
#
# Perform the following tasks:
# 1. Add a new key-value pair to the dictionary to store the river's average discharge (e.g., 209000 m³/s).
# 2. Update the length of the river to 6992 km.
# 3. Print the dictionary

# %%
amazon_river = {
    'name': 'Amazon River',
    'length': '6.400 km',
    'countries': ['Brazil', 'Peru', 'Colombia'],
    'spring': 'Cordilheira dos Andes'
}

print(amazon_river)

amazon_river['avg_discharge'] = '209.000,00 m³/s'
amazon_river['length'] = '6.992 km'

print(amazon_river)
# Out:
# {'name': 'Amazon River', 'length': '6.400 km', 'countries': ['Brazil', 'Peru', 'Colombia'], 'spring': 'Cordilheira dos Andes'}
# {'name': 'Amazon River', 'length': '6.992 km', 'countries': ['Brazil', 'Peru', 'Colombia'], 'spring': 'Cordilheira dos Andes', 'avg_discharge': '209.000,00 m³/s'}

# %% [markdown]
# ### Exercise 5: Neste Data Structures
# Create a dictionary to represent a city that contains the city's name, population, and coordiantes (latitude, longitude):
# - Name: “Tokyo”
# - Population: 13,515,271
# - Coordinates: (35.6895, 139.6917)
#
# Perform the following tasks:
# 1. Access and print the population of the city.
# 2. Access and print the city's latitude
# 3. Update the population to 14000000 and print the updated dictionary

# %%
japan_cities = {
    'name': 'Tokyo',
    'population': 13515271,
    'coordinates': (35.6895, 139.6917)
}

print(f'Population: {japan_cities['population']:,}')
print(f'Latitude: {japan_cities['coordinates'][0]}')

japan_cities['population'] = 14000000

print(japan_cities)
# Out:
# Population: 13,515,271
# Latitude: 35.6895
# {'name': 'Tokyo', 'population': 14000000, 'coordinates': (35.6895, 139.6917)}
